# %% [markdown]
# <a href="https://colab.research.google.com/github/amitraghatate/Basic-of-Python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#+ve indexing and +ve slicing
var_str = 'Yeh Tera Ghar Yeh Mera Ghar'
var_str
# Out:
# 'Yeh Tera Ghar Yeh Mera Ghar'

# %%
print(var_str[::])
print(var_str[0::])
print(var_str[:len(var_str)])
print(var_str[::1])
# Out:
# Yeh Tera Ghar Yeh Mera Ghar
# Yeh Tera Ghar Yeh Mera Ghar
# Yeh Tera Ghar Yeh Mera Ghar
# Yeh Tera Ghar Yeh Mera Ghar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#-ve indexing and -ve slicing
var_str
# Out:
# 'Yeh Tera Ghar Yeh Mera Ghar'

# %%
print(var_str[::-1])
print(var_str[-1::-1])
print(var_str[:-len(var_str):-1])
print(var_str[-1:-5:-1])
print(var_str[-6:-10:-1])
print(var_str[-11:-14:-1])
print(var_str[-15:-19:-1])
print(var_str[-20:-24:-1])
print(var_str[-25::-1])
# Out:
# rahG areM heY rahG areT heY
# rahG areM heY rahG areT heY
# rahG areM heY rahG areT he
# rahG
# areM
# heY
# rahG
# areT
# heY

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#-ve indexing ahe +ve slicing
var_str
# Out:
# 'Yeh Tera Ghar Yeh Mera Ghar'

# %%
print(var_str[-27::1])
print(var_str[-27:-24:])
print(var_str[-27:-19:])
print(var_str[:-14])
print(var_str[:-10])
print(var_str[:-6])
print(var_str[:])
# Out:
# Yeh Tera Ghar Yeh Mera Ghar
# Yeh
# Yeh Tera
# Yeh Tera Ghar
# Yeh Tera Ghar Yeh
# Yeh Tera Ghar Yeh Mer
# Yeh Tera Ghar Yeh Mera Ghar

# %%
print(var_str[-27:-24:1])
print(var_str[-23:-19])
print(var_str[-18:-14])
print(var_str[-13:-10])
print(var_str[-9:-5])
print(var_str[-4:])
# Out:
# Yeh
# Tera
# Ghar
# Yeh
# Mera
# Ghar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#+ve indexing and -ve slicing
var_str
# Out:
# 'Yeh Tera Ghar Yeh Mera Ghar'

# %%
print(var_str[::-1])
print(var_str[27::-1])
print(var_str[21::-1])
print(var_str[16::-1])
print(var_str[12::-1])
print(var_str[7::-1])
print(var_str[2::-1])
print(len(var_str))
# Out:
# rahG areM heY rahG areT heY
# rahG areM heY rahG areT heY
# areM heY rahG areT heY
# heY rahG areT heY
# rahG areT heY
# areT heY
# heY
# 27

# %%
print(var_str[2::-1])
print(var_str[7:3:-1])
print(var_str[12:8:-1])
print(var_str[16:13:-1])
print(var_str[21:17:-1])
print(var_str[26:22:-1])
# Out:
# heY
# areT
# rahG
# heY
# areM
# rahG
